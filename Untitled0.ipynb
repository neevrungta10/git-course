# %% [markdown]
# <a href="https://colab.research.google.com/github/neevrungta10/git-course/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world\n")
# Out:
# hello world

# %%
a=2
b=2
c=a/b
print(c)
d="I like it"
print(d,"and it suits me well")
# Out:
# 1.0
# I like it and it suits me well

# %%
n = int(input("Enter number of elements: "))

lst = []
for i in range(n):
    x = int(input())
    lst.append(x)

print(lst)
# Out:
# Enter number of elements: 4
# 1
# 2
# 3
# 4
# [1, 2, 3, 4]
